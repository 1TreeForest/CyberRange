# %%
import csv
import re
import pandas as pd
import numpy as np
import pymysql

# %%
pd_reader = pd.read_csv("result_data.csv")
pattern = re.compile(r'//(.+)')

# %%
import pymysql
conn = pymysql.Connect(  # 配置数据库
    host='1.15.220.155',
    port=3306,
    user='test',
    password='991125',
    db='spider',
    charset='UTF8'
)
cursor = conn.cursor()

# %%
sql = 'select distinct app_sequence from cluster'
cursor.execute(sql)
res = cursor.fetchall()
n = 0
for i in res:
    sql = 'update cluster set app_code = %s where app_sequence = %s'
    cursor.execute(sql,[n,i[0]])
    n+=1
    conn.commit()

# %%
print(pd_reader.shape)
for row in range(12566):
    try:
        domain = pattern.search(str(pd_reader.iloc[row]))[1]
    except:
        continue
    sequence = ''
    for col in range(7, 75):
        sequence += str(pd_reader.iloc[row][col])
    print(len(sequence))
    cursor.execute('update cluster set app_sequence = %s where domain = %s', [sequence, domain])
    conn.commit()
# Out:
# (12566, 75)
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# ...

# %%
for row in range(12566):
    try:
        domain = pattern.search(str(pd_reader.iloc[row]))[1]
    except:
        continue
    title = ''
    body_len = ''
    title = pd_reader.iloc[row]['title']
    body_len = pd_reader.iloc[row]['body length']
    try:
        cursor.execute('update cluster set title = %s, body_len = %s where domain = %s', [title, body_len, domain])
    except:
        continue
    conn.commit()
